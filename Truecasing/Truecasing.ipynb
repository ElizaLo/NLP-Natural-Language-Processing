# %% [markdown]
# # Truecasing

# %%
# !pip3 install truecase

# %%
# !pip install stanfordnlp

# %%
import pandas as pd
import re, os
import boto3
import warnings

import nltk
nltk.download('words')
nltk.download('punkt')


warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = '''Hawaii comprises nearly the entire Hawaiian archipelago, 137 volcanic islands spanning 1,500 miles (2,400 km) that are physiographically and ethnologically part of the Polynesian subregion of Oceania. The state's ocean coastline is consequently the fourth-longest in the U.S., at about 750 miles (1,210 km).[b] The eight main islands, from northwest to southeast, are Niʻihau, Kauaʻi, Oʻahu, Molokaʻi, Lānaʻi, Kahoʻolawe, Maui, and Hawaiʻi—the last of these, after which the state is named, is often called the "Big Island" or "Hawaii Island" to avoid confusion with the state or archipelago. The uninhabited Northwestern Hawaiian Islands make up most of the Papahānaumokuākea Marine National Monument, the United States' largest protected area and the fourth-largest in the world. Of the 50 U.S. states, Hawaii is the eighth-smallest in land area and the 11th-least populous, but with 1.4 million residents ranks 13th in population density. Two-thirds of the population lives on O'ahu, home to the state's capital and largest city, Honolulu. Hawaii is among the country's most diverse states, owing to its central location in the Pacific and over two centuries of migration. As one of only six majority-minority states, it has the country's only Asian American plurality, its largest Buddhist community, and the largest proportion of multiracial people. Consequently, it is a unique melting pot of North American and East Asian cultures, in addition to its indigenous Hawaiian heritage. Settled by Polynesians some time between 1000 and 1200 CE, Hawaii was home to numerous independent chiefdoms. In 1778, British explorer James Cook was the first known non-Polynesian to arrive at the archipelago; early British influence is reflected in the state flag, which bears a Union Jack. An influx of European and American explorers, traders, and whalers arrived shortly after leading to the decimation of the once isolated Indigenous community by introducing diseases such as syphilis, gonorrhea, tuberculosis, smallpox, measles, leprosy, and typhoid fever, reducing the native Hawaiian population from between 300,000 and one million to less than 40,000 by 1890. Hawaii became a unified, internationally recognized kingdom in 1810, remaining independent until American and European businessmen overthrew the monarchy in 1893; this led to annexation by the U.S. in 1898. As a strategically valuable U.S. territory, Hawaii was attacked by Japan on December 7, 1941, which brought it global and historical significance, and contributed to America's decisive entry into World War II. Hawaii is the most recent state to join the union, on August 21, 1959. In 1993, the U.S. government formally apologized for its role in the overthrow of Hawaii's government, which spurred the Hawaiian sovereignty movement.'''
text
# Out:
# 'Hawaii comprises nearly the entire Hawaiian archipelago, 137 volcanic islands spanning 1,500 miles (2,400\xa0km) that are physiographically and ethnologically part of the Polynesian subregion of Oceania. The state\'s ocean coastline is consequently the fourth-longest in the U.S., at about 750 miles (1,210\xa0km).[b] The eight main islands, from northwest to southeast, are Niʻihau, Kauaʻi, Oʻahu, Molokaʻi, Lānaʻi, Kahoʻolawe, Maui, and Hawaiʻi—the last of these, after which the state is named, is often called the "Big Island" or "Hawaii Island" to avoid confusion with the state or archipelago. The uninhabited Northwestern Hawaiian Islands make up most of the Papahānaumokuākea Marine National Monument, the United States\' largest protected area and the fourth-largest in the world. Of the 50 U.S. states, Hawaii is the eighth-smallest in land area and the 11th-least populous, but with 1.4\xa0million residents ranks 13th in population density. Two-thirds of the population lives on O\'ahu, home to the state\'s capital and largest city, Honolulu. Hawaii is among the country\'s most diverse states, owing to its central location in the Pacific and over two centuries of migration. As one of only six majority-minority states, it has the country\'s only Asian American plurality, its largest Buddhist community, and the largest proportion of multiracial people. Consequently, it is a unique melting pot of North American and East Asian cultures, in addition to its indigenous Hawaiian heritage. Settled by Polynesians some time between 1000 and 1200 CE, Hawaii was home to numerous independent chiefdoms. In 1778, British explorer James Cook was the first known non-Polynesian to arrive at the archipelago; early British influence is reflected in the state flag, which bears a Union Jack. An influx of European and American explorers, traders, and whalers arrived shortly after leading to the decimation of the once isolated Indigenous community by introducing diseases such as syphilis, gonorrhea, tuberculosis, smallpox, measles, leprosy, and typhoid fever, reducing the native Hawaiian population from between 300,000 and one million to less than 40,000 by 1890. Hawaii became a unified, internationally recognized kingdom in 1810, remaining independent until American and European businessmen overthrew the monarchy in 1893; this led to annexation by the U.S. in 1898. As a strategically valuable U.S. territory, Hawaii was attacked by Japan on December 7, 1941, which brought it global and historical significance, and contributed to America\'s decisive entry into World War II. Hawaii is the most recent state to join the union, on August 21, 1959. In 1993, the U.S. government formally apologized for its role in the overthrow of Hawaii\'s government, which spurred the Hawaiian sovereignty movement.'

# %%
text = text.lower()

# %% [markdown]
# # TrueCase
#
# - [TrueCase](https://pypi.org/project/truecase/)
#
# The model was inspired by the paper of [Lucian Vlad Lita et al., tRuEcasIng](https://www.cs.cmu.edu/~llita/papers/lita.truecasing-acl2003.pdf) but with some simplifications.
#
# A model trained on NLTK English corpus comes with the package by default, and for other languages, a script is provided to create the model. This model is not perfect, train the system on a large and recent dataset to achieve the best results (e.g. on a recent dump of Wikipedia).

# %%
import truecase

# %%
truecase.get_true_case(text)
# Out:
# 'Hawaii comprises nearly the entire Hawaiian archipelago, 137 volcanic Islands spanning 1,500 miles (2,400 km) that are Physiographically and Ethnologically part of the Polynesian Subregion of Oceania . The state\'s ocean coastline is consequently the Fourth-Longest in the U.S., at about 750 miles (1,210 km). [B] the eight main Islands, from Northwest to Southeast, are NiʻIhau, KauaʻI, OʻAhu, MolokaʻI, LānaʻI, KahoʻOlawe, Maui, and HawaiʻI—The last of these, after which the state is named, is often called the "big Island" or "Hawaii Island" to avoid confusion with the state or archipelago . The Uninhabited Northwestern Hawaiian Islands make up most of the Papahānaumokuākea Marine national monument, the United States\' largest protected area and the fourth-largest in the world . of the 50 U.S. States, Hawaii is the Eighth-Smallest in land area and the 11Th-Least populous, but with 1.4 million residents ranks 13th in population density . two-thirds of the population lives on O\'Ahu, home to the state\'s capital and largest city, Honolulu . Hawaii is among the country\'s most diverse States, owing to its central location in the Pacific and over two centuries of migration . as one of only six Majority-Minority States, it has the country\'s only Asian American plurality, its largest Buddhist community, and the largest proportion of Multiracial people . Consequently, it is a unique melting pot of North American and East Asian cultures, in addition to its indigenous Hawaiian heritage . settled by Polynesians some time between 1000 and 1200 Ce, Hawaii was home to numerous independent chiefdoms . In 1778, British explorer James Cook was the first known Non-Polynesian to arrive at the archipelago; early British influence is reflected in the state flag, which bears a union Jack . An influx of European and American explorers, traders, and Whalers arrived shortly after leading to the Decimation of the once isolated indigenous community by introducing diseases such as Syphilis, Gonorrhea, tuberculosis, smallpox, measles, leprosy, and typhoid fever, reducing the native Hawaiian population from between 300,000 and one million to less than 40,000 by 1890. Hawaii became a unified, internationally recognized Kingdom in 1810, remaining independent until American and European businessmen Overthrew the Monarchy in 1893; this led to Annexation by the U.S. in 1898. as a strategically valuable U.S. territory, Hawaii was attacked by Japan on December 7, 1941, which brought it global and historical significance, and contributed to America\'s decisive entry into World War II . Hawaii is the most recent state to join the Union, on August 21, 1959. in 1993, the U.S. government formally apologized for its role in the overthrow of Hawaii\'s government, which spurred the Hawaiian sovereignty movement.'

# %% [markdown]
# # StandfordNLP
#
# - [TrueCaseAnnotator](https://stanfordnlp.github.io/CoreNLP/truecase.html) by CoreNLP

# %%
import stanfordnlp

stanfordnlp.download('en')
# Out:
# Using the default treebank "en_ewt" for language "en".
# Would you like to download the models for: en_ewt now? (Y/n)
#  Y
# Default download directory: /root/stanfordnlp_resources
# Hit enter to continue or type an alternate directory.
# Downloading models for: en_ewt
# Download location: /root/stanfordnlp_resources/en_ewt_models.zip
# 100%|██████████| 235M/235M [00:40<00:00, 5.87MB/s]
# Download complete.  Models saved to: /root/stanfordnlp_resources/en_ewt_models.zip
# Extracting models file for: en_ewt
# Cleaning up...Done.

# %%
stf_nlp = stanfordnlp.Pipeline(processors='tokenize,mwt,pos')

doc = stf_nlp(text)

print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in 
        doc.sentences for word in sent.words], sep='\n')
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/root/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/root/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/root/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# word: hawaii 	upos: PROPN	xpos: NNP
# word: comprises 	upos: VERB	xpos: VBZ
# word: nearly 	upos: ADV	xpos: RB
# word: the 	upos: DET	xpos: DT
# word: entire 	upos: ADJ	xpos: JJ
# word: hawaiian 	upos: ADJ	xpos: JJ
# word: archipelago 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: 137 	upos: NUM	xpos: CD
# word: volcanic 	upos: ADJ	xpos: JJ
# word: islands 	upos: NOUN	xpos: NNS
# word: spanning 	upos: VERB	xpos: VBG
# word: 1,500 	upos: NUM	xpos: CD
# word: miles 	upos: NOUN	xpos: NNS
# word: ( 	upos: PUNCT	xpos: -LRB-
# word: 2,400 	upos: NUM	xpos: CD
# word: km 	upos: NOUN	xpos: NNS
# word: ) 	upos: PUNCT	xpos: -RRB-
# word: that 	upos: PRON	xpos: WDT
# word: are 	upos: AUX	xpos: VBP
# word: physiographically 	upos: ADV	xpos: RB
# word: and 	upos: CCONJ	xpos: CC
# word: ethnologically 	upos: ADV	xpos: RB
# word: part 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: polynesian 	upos: ADJ	xpos: JJ
# word: subregion 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: oceania 	upos: PROPN	xpos: NNP
# word: . 	upos: PUNCT	xpos: .
# word: the 	upos: DET	xpos: DT
# word: state 	upos: NOUN	xpos: NN
# word: 's 	upos: PART	xpos: POS
# word: ocean 	upos: ADJ	xpos: JJ
# word: coastline 	upos: NOUN	xpos: NN
# word: is 	upos: AUX	xpos: VBZ
# word: consequently 	upos: ADV	xpos: RB
# word: the 	upos: DET	xpos: DT
# word: fourth 	upos: ADJ	xpos: JJ
# word: - 	upos: PUNCT	xpos: HYPH
# word: longest 	upos: ADJ	xpos: JJS
# word: in 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: u.s. 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: at 	upos: ADP	xpos: IN
# word: about 	upos: ADV	xpos: RB
# word: 750 	upos: NUM	xpos: CD
# word: miles 	upos: NOUN	xpos: NNS
# word: ( 	upos: PUNCT	xpos: -LRB-
# word: 1,210 	upos: NUM	xpos: CD
# word: km 	upos: NOUN	xpos: NN
# word: ) 	upos: PUNCT	xpos: -RRB-
# word: . 	upos: PUNCT	xpos: .
# word: [ 	upos: PUNCT	xpos: -LRB-
# word: b 	upos: X	xpos: LS
# word: ] 	upos: PUNCT	xpos: -RRB-
# word: the 	upos: DET	xpos: DT
# word: eight 	upos: NUM	xpos: CD
# word: main 	upos: ADJ	xpos: JJ
# word: islands 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: from 	upos: ADP	xpos: IN
# word: northwest 	upos: NOUN	xpos: NN
# word: to 	upos: ADP	xpos: IN
# word: southeast 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: are 	upos: AUX	xpos: VBP
# word: niʻihau 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: kauaʻi 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: oʻahu 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: molokaʻi 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: lānaʻi 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: kahoʻolawe 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: maui 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: and 	upos: CCONJ	xpos: CC
# word: hawaiʻi—the 	upos: PROPN	xpos: NNP
# word: last 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: these 	upos: PRON	xpos: DT
# word: , 	upos: PUNCT	xpos: ,
# word: after 	upos: ADP	xpos: IN
# word: which 	upos: PRON	xpos: WDT
# word: the 	upos: DET	xpos: DT
# word: state 	upos: NOUN	xpos: NN
# word: is 	upos: AUX	xpos: VBZ
# word: named 	upos: VERB	xpos: VBN
# word: , 	upos: PUNCT	xpos: ,
# word: is 	upos: AUX	xpos: VBZ
# word: often 	upos: ADV	xpos: RB
# word: called 	upos: VERB	xpos: VBN
# word: the 	upos: DET	xpos: DT
# word: " 	upos: PUNCT	xpos: ``
# word: big 	upos: ADJ	xpos: JJ
# word: island 	upos: NOUN	xpos: NN
# word: " 	upos: PUNCT	xpos: ''
# word: or 	upos: CCONJ	xpos: CC
# word: " 	upos: PUNCT	xpos: ``
# word: hawaii 	upos: PROPN	xpos: NNP
# word: island 	upos: NOUN	xpos: NN
# word: " 	upos: PUNCT	xpos: ''
# word: to 	upos: PART	xpos: TO
# word: avoid 	upos: VERB	xpos: VB
# word: confusion 	upos: NOUN	xpos: NN
# word: with 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: state 	upos: NOUN	xpos: NN
# word: or 	upos: CCONJ	xpos: CC
# word: archipelago 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .
# word: the 	upos: DET	xpos: DT
# word: uninhabited 	upos: ADJ	xpos: JJ
# word: northwestern 	upos: ADJ	xpos: JJ
# word: hawaiian 	upos: ADJ	xpos: JJ
# word: islands 	upos: NOUN	xpos: NNS
# word: make 	upos: VERB	xpos: VBP
# word: up 	upos: ADP	xpos: RP
# word: most 	upos: ADJ	xpos: JJS
# word: of 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: papah 	upos: ADJ	xpos: JJ
# word: ā 	upos: NOUN	xpos: NN
# word: naumokuākea 	upos: ADJ	xpos: JJ
# word: marine 	upos: NOUN	xpos: NN
# word: national 	upos: ADJ	xpos: JJ
# word: monument 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: the 	upos: DET	xpos: DT
# word: united 	upos: PROPN	xpos: NNP
# word: states 	upos: PROPN	xpos: NNP
# word: ' 	upos: PART	xpos: POS
# word: largest 	upos: ADJ	xpos: JJS
# word: protected 	upos: VERB	xpos: VBN
# word: area 	upos: NOUN	xpos: NN
# word: and 	upos: CCONJ	xpos: CC
# word: the 	upos: DET	xpos: DT
# word: fourth 	upos: ADJ	xpos: JJ
# word: - 	upos: PUNCT	xpos: HYPH
# word: largest 	upos: ADJ	xpos: JJS
# word: in 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: world 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .
# word: of 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: 50 	upos: NUM	xpos: CD
# word: u.s. 	upos: PROPN	xpos: NNP
# word: states 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: hawaii 	upos: PROPN	xpos: NNP
# word: is 	upos: AUX	xpos: VBZ
# word: the 	upos: DET	xpos: DT
# word: eighth 	upos: ADJ	xpos: JJ
# word: - 	upos: PUNCT	xpos: HYPH
# word: smallest 	upos: ADJ	xpos: JJS
# word: in 	upos: ADP	xpos: IN
# word: land 	upos: NOUN	xpos: NN
# word: area 	upos: NOUN	xpos: NN
# word: and 	upos: CCONJ	xpos: CC
# word: the 	upos: DET	xpos: DT
# word: 11th 	upos: ADJ	xpos: JJ
# word: - 	upos: ADV	xpos: RB
# word: least 	upos: ADV	xpos: RBS
# word: populous 	upos: ADJ	xpos: JJ
# word: , 	upos: PUNCT	xpos: ,
# word: but 	upos: CCONJ	xpos: CC
# word: with 	upos: ADP	xpos: IN
# word: 1.4 	upos: NUM	xpos: CD
# word: million 	upos: NUM	xpos: CD
# word: residents 	upos: NOUN	xpos: NNS
# word: ranks 	upos: NOUN	xpos: NNS
# word: 13th 	upos: NOUN	xpos: NN
# word: in 	upos: ADP	xpos: IN
# word: population 	upos: NOUN	xpos: NN
# word: density 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .
# word: two 	upos: NUM	xpos: CD
# word: - 	upos: PUNCT	xpos: :
# word: thirds 	upos: NOUN	xpos: NNS
# word: of 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: population 	upos: NOUN	xpos: NN
# word: lives 	upos: NOUN	xpos: NNS
# word: on 	upos: ADP	xpos: IN
# word: o'ahu 	upos: PROPN	xpos: NNP
# word: , 	upos: PUNCT	xpos: ,
# word: home 	upos: NOUN	xpos: NN
# word: to 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: state 	upos: NOUN	xpos: NN
# word: 's 	upos: PART	xpos: POS
# word: capital 	upos: NOUN	xpos: NN
# word: and 	upos: CCONJ	xpos: CC
# word: largest 	upos: ADJ	xpos: JJS
# word: city 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: honolulu 	upos: PROPN	xpos: NNP
# word: . 	upos: PUNCT	xpos: .
# word: hawaii 	upos: PROPN	xpos: NNP
# word: is 	upos: AUX	xpos: VBZ
# word: among 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: country 	upos: NOUN	xpos: NN
# word: 's 	upos: PART	xpos: POS
# word: most 	upos: ADV	xpos: RBS
# word: diverse 	upos: ADJ	xpos: JJ
# word: states 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: owing 	upos: VERB	xpos: VBG
# word: to 	upos: ADP	xpos: IN
# word: its 	upos: PRON	xpos: PRP$
# word: central 	upos: ADJ	xpos: JJ
# word: location 	upos: NOUN	xpos: NN
# word: in 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: pacific 	upos: PROPN	xpos: NNP
# word: and 	upos: CCONJ	xpos: CC
# word: over 	upos: ADP	xpos: IN
# word: two 	upos: NUM	xpos: CD
# word: centuries 	upos: NOUN	xpos: NNS
# word: of 	upos: ADP	xpos: IN
# word: migration 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .
# word: as 	upos: ADP	xpos: IN
# word: one 	upos: NUM	xpos: CD
# word: of 	upos: ADP	xpos: IN
# word: only 	upos: ADV	xpos: RB
# word: six 	upos: NUM	xpos: CD
# word: majority 	upos: NOUN	xpos: NN
# word: - 	upos: PUNCT	xpos: HYPH
# word: minority 	upos: ADJ	xpos: JJ
# word: states 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: it 	upos: PRON	xpos: PRP
# word: has 	upos: VERB	xpos: VBZ
# word: the 	upos: DET	xpos: DT
# word: country 	upos: NOUN	xpos: NN
# word: 's 	upos: PART	xpos: POS
# word: only 	upos: ADV	xpos: RB
# word: asian 	upos: ADJ	xpos: JJ
# word: american 	upos: ADJ	xpos: JJ
# word: plurality 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: its 	upos: PRON	xpos: PRP$
# word: largest 	upos: ADJ	xpos: JJS
# word: buddhist 	upos: ADJ	xpos: JJ
# word: community 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: and 	upos: CCONJ	xpos: CC
# word: the 	upos: DET	xpos: DT
# word: largest 	upos: ADJ	xpos: JJS
# word: proportion 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: multiracial 	upos: ADJ	xpos: JJ
# word: people 	upos: NOUN	xpos: NNS
# word: . 	upos: PUNCT	xpos: .
# word: consequently 	upos: ADV	xpos: RB
# word: , 	upos: PUNCT	xpos: ,
# word: it 	upos: PRON	xpos: PRP
# word: is 	upos: AUX	xpos: VBZ
# word: a 	upos: DET	xpos: DT
# word: unique 	upos: ADJ	xpos: JJ
# word: melting 	upos: NOUN	xpos: NN
# word: pot 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: north 	upos: ADJ	xpos: JJ
# word: american 	upos: ADJ	xpos: JJ
# word: and 	upos: CCONJ	xpos: CC
# word: east 	upos: ADJ	xpos: JJ
# word: asian 	upos: ADJ	xpos: JJ
# word: cultures 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: in 	upos: ADP	xpos: IN
# word: addition 	upos: NOUN	xpos: NN
# word: to 	upos: ADP	xpos: IN
# word: its 	upos: PRON	xpos: PRP$
# word: indigenous 	upos: ADJ	xpos: JJ
# word: hawaiian 	upos: ADJ	xpos: JJ
# word: heritage 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .
# word: settled 	upos: VERB	xpos: VBN
# word: by 	upos: ADP	xpos: IN
# word: polynesians 	upos: PROPN	xpos: NNPS
# word: some 	upos: DET	xpos: DT
# word: time 	upos: NOUN	xpos: NN
# word: between 	upos: ADP	xpos: IN
# word: 1000 	upos: NUM	xpos: CD
# word: and 	upos: CCONJ	xpos: CC
# word: 1200 	upos: NUM	xpos: CD
# word: ce 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: hawaii 	upos: PROPN	xpos: NNP
# word: was 	upos: AUX	xpos: VBD
# word: home 	upos: ADV	xpos: RB
# word: to 	upos: ADP	xpos: IN
# word: numerous 	upos: ADJ	xpos: JJ
# word: independent 	upos: ADJ	xpos: JJ
# word: chiefdoms 	upos: NOUN	xpos: NNS
# word: . 	upos: PUNCT	xpos: .
# word: in 	upos: ADP	xpos: IN
# word: 1778 	upos: NUM	xpos: CD
# word: , 	upos: PUNCT	xpos: ,
# word: british 	upos: ADJ	xpos: JJ
# word: explorer 	upos: NOUN	xpos: NN
# word: james 	upos: NOUN	xpos: NNS
# word: cook 	upos: NOUN	xpos: NN
# word: was 	upos: AUX	xpos: VBD
# word: the 	upos: DET	xpos: DT
# word: first 	upos: ADV	xpos: RB
# word: known 	upos: VERB	xpos: VBN
# word: non-polynesian 	upos: ADJ	xpos: JJ
# word: to 	upos: PART	xpos: TO
# word: arrive 	upos: VERB	xpos: VB
# word: at 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: archipelago 	upos: NOUN	xpos: NN
# word: ; 	upos: PUNCT	xpos: ,
# word: early 	upos: ADJ	xpos: JJ
# word: british 	upos: ADJ	xpos: JJ
# word: influence 	upos: NOUN	xpos: NN
# word: is 	upos: AUX	xpos: VBZ
# word: reflected 	upos: VERB	xpos: VBN
# word: in 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: state 	upos: NOUN	xpos: NN
# word: flag 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: which 	upos: PRON	xpos: WDT
# word: bears 	upos: VERB	xpos: VBZ
# word: a 	upos: DET	xpos: DT
# word: union 	upos: NOUN	xpos: NN
# word: jack 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .
# word: an 	upos: DET	xpos: DT
# word: influx 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: european 	upos: ADJ	xpos: JJ
# word: and 	upos: CCONJ	xpos: CC
# word: american 	upos: ADJ	xpos: JJ
# word: explorers 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: traders 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: and 	upos: CCONJ	xpos: CC
# word: whalers 	upos: NOUN	xpos: NNS
# word: arrived 	upos: VERB	xpos: VBD
# word: shortly 	upos: ADV	xpos: RB
# word: after 	upos: SCONJ	xpos: IN
# word: leading 	upos: VERB	xpos: VBG
# word: to 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: decimation 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: once 	upos: ADV	xpos: RB
# word: isolated 	upos: VERB	xpos: VBN
# word: indigenous 	upos: ADJ	xpos: JJ
# word: community 	upos: NOUN	xpos: NN
# word: by 	upos: SCONJ	xpos: IN
# word: introducing 	upos: VERB	xpos: VBG
# word: diseases 	upos: NOUN	xpos: NNS
# word: such 	upos: ADJ	xpos: JJ
# word: as 	upos: ADP	xpos: IN
# word: syphilis 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: gonorrhea 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: tuberculosis 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: smallpox 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: measles 	upos: NOUN	xpos: NNS
# word: , 	upos: PUNCT	xpos: ,
# word: leprosy 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: and 	upos: CCONJ	xpos: CC
# word: typhoid 	upos: NOUN	xpos: NN
# word: fever 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: reducing 	upos: VERB	xpos: VBG
# word: the 	upos: DET	xpos: DT
# word: native 	upos: ADJ	xpos: JJ
# word: hawaiian 	upos: ADJ	xpos: JJ
# word: population 	upos: NOUN	xpos: NN
# word: from 	upos: ADP	xpos: IN
# word: between 	upos: ADP	xpos: IN
# word: 300,000 	upos: NUM	xpos: CD
# word: and 	upos: CCONJ	xpos: CC
# word: one 	upos: NUM	xpos: CD
# word: million 	upos: NUM	xpos: CD
# word: to 	upos: ADP	xpos: IN
# word: less 	upos: ADJ	xpos: JJR
# word: than 	upos: ADP	xpos: IN
# word: 40,000 	upos: NUM	xpos: CD
# word: by 	upos: ADP	xpos: IN
# word: 1890 	upos: NUM	xpos: CD
# word: . 	upos: PUNCT	xpos: .
# word: hawaii 	upos: PROPN	xpos: NNP
# word: became 	upos: VERB	xpos: VBD
# word: a 	upos: DET	xpos: DT
# word: unified 	upos: ADJ	xpos: JJ
# word: , 	upos: PUNCT	xpos: ,
# word: internationally 	upos: ADV	xpos: RB
# word: recognized 	upos: VERB	xpos: VBN
# word: kingdom 	upos: NOUN	xpos: NN
# word: in 	upos: ADP	xpos: IN
# word: 1810 	upos: NUM	xpos: CD
# word: , 	upos: PUNCT	xpos: ,
# word: remaining 	upos: VERB	xpos: VBG
# word: independent 	upos: ADJ	xpos: JJ
# word: until 	upos: ADP	xpos: IN
# word: american 	upos: ADJ	xpos: JJ
# word: and 	upos: CCONJ	xpos: CC
# word: european 	upos: ADJ	xpos: JJ
# word: businessmen 	upos: NOUN	xpos: NNS
# word: overthrew 	upos: VERB	xpos: VBD
# word: the 	upos: DET	xpos: DT
# word: monarchy 	upos: NOUN	xpos: NN
# word: in 	upos: ADP	xpos: IN
# word: 1893 	upos: NUM	xpos: CD
# word: ; 	upos: PUNCT	xpos: ,
# word: this 	upos: PRON	xpos: DT
# word: led 	upos: VERB	xpos: VBD
# word: to 	upos: ADP	xpos: IN
# word: annexation 	upos: NOUN	xpos: NN
# word: by 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: u.s. 	upos: PROPN	xpos: NNP
# word: in 	upos: ADP	xpos: IN
# word: 1898 	upos: NUM	xpos: CD
# word: . 	upos: PUNCT	xpos: .
# word: as 	upos: ADP	xpos: IN
# word: a 	upos: DET	xpos: DT
# word: strategically 	upos: ADV	xpos: RB
# word: valuable 	upos: ADJ	xpos: JJ
# word: u.s. 	upos: PROPN	xpos: NNP
# word: territory 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: hawaii 	upos: PROPN	xpos: NNP
# word: was 	upos: AUX	xpos: VBD
# word: attacked 	upos: VERB	xpos: VBN
# word: by 	upos: ADP	xpos: IN
# word: japan 	upos: PROPN	xpos: NNP
# word: on 	upos: ADP	xpos: IN
# word: december 	upos: PROPN	xpos: NNP
# word: 7 	upos: NUM	xpos: CD
# word: , 	upos: PUNCT	xpos: ,
# word: 1941 	upos: NUM	xpos: CD
# word: , 	upos: PUNCT	xpos: ,
# word: which 	upos: PRON	xpos: WDT
# word: brought 	upos: VERB	xpos: VBD
# word: it 	upos: PRON	xpos: PRP
# word: global 	upos: ADJ	xpos: JJ
# word: and 	upos: CCONJ	xpos: CC
# word: historical 	upos: ADJ	xpos: JJ
# word: significance 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: and 	upos: CCONJ	xpos: CC
# word: contributed 	upos: VERB	xpos: VBD
# word: to 	upos: ADP	xpos: IN
# word: america 	upos: PROPN	xpos: NNP
# word: 's 	upos: PART	xpos: POS
# word: decisive 	upos: ADJ	xpos: JJ
# word: entry 	upos: NOUN	xpos: NN
# word: into 	upos: ADP	xpos: IN
# word: world 	upos: NOUN	xpos: NN
# word: war 	upos: NOUN	xpos: NN
# word: ii 	upos: NUM	xpos: CD
# word: . 	upos: PUNCT	xpos: .
# word: hawaii 	upos: PROPN	xpos: NNP
# word: is 	upos: AUX	xpos: VBZ
# word: the 	upos: DET	xpos: DT
# word: most 	upos: ADV	xpos: RBS
# word: recent 	upos: ADJ	xpos: JJ
# word: state 	upos: NOUN	xpos: NN
# word: to 	upos: PART	xpos: TO
# word: join 	upos: VERB	xpos: VB
# word: the 	upos: DET	xpos: DT
# word: union 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: on 	upos: ADP	xpos: IN
# word: august 	upos: PROPN	xpos: NNP
# word: 21 	upos: NUM	xpos: CD
# word: , 	upos: PUNCT	xpos: ,
# word: 1959 	upos: NUM	xpos: CD
# word: . 	upos: PUNCT	xpos: .
# word: in 	upos: ADP	xpos: IN
# word: 1993 	upos: NUM	xpos: CD
# word: , 	upos: PUNCT	xpos: ,
# word: the 	upos: DET	xpos: DT
# word: u.s. 	upos: PROPN	xpos: NNP
# word: government 	upos: NOUN	xpos: NN
# word: formally 	upos: ADV	xpos: RB
# word: apologized 	upos: VERB	xpos: VBD
# word: for 	upos: ADP	xpos: IN
# word: its 	upos: PRON	xpos: PRP$
# word: role 	upos: NOUN	xpos: NN
# word: in 	upos: ADP	xpos: IN
# word: the 	upos: DET	xpos: DT
# word: overthrow 	upos: NOUN	xpos: NN
# word: of 	upos: ADP	xpos: IN
# word: hawaii 	upos: PROPN	xpos: NNP
# word: 's 	upos: PART	xpos: POS
# word: government 	upos: NOUN	xpos: NN
# word: , 	upos: PUNCT	xpos: ,
# word: which 	upos: PRON	xpos: WDT
# word: spurred 	upos: VERB	xpos: VBD
# word: the 	upos: DET	xpos: DT
# word: hawaiian 	upos: ADJ	xpos: JJ
# word: sovereignty 	upos: NOUN	xpos: NN
# word: movement 	upos: NOUN	xpos: NN
# word: . 	upos: PUNCT	xpos: .

# %%
[w.text.capitalize() if w.upos in ["PROPN","NNS"] else w.text for sent in 
 doc.sentences for w in sent.words]
# Out:
# ['Hawaii',
#  'comprises',
#  'nearly',
#  'the',
#  'entire',
#  'hawaiian',
#  'archipelago',
#  ',',
#  '137',
#  'volcanic',
#  'islands',
#  'spanning',
#  '1,500',
#  'miles',
#  '(',
#  '2,400',
#  'km',
#  ')',
#  'that',
#  'are',
#  'physiographically',
#  'and',
#  'ethnologically',
#  'part',
#  'of',
#  'the',
#  'polynesian',
#  'subregion',
#  'of',
#  'Oceania',
#  '.',
#  'the',
#  'state',
#  "'s",
#  'ocean',
#  'coastline',
#  'is',
#  'consequently',
#  'the',
#  'fourth',
#  '-',
#  'longest',
#  'in',
#  'the',
#  'U.s.',
#  ',',
#  'at',
#  'about',
#  '750',
#  'miles',
#  '(',
#  '1,210',
#  'km',
#  ')',
#  '.',
#  '[',
#  'b',
#  ']',
#  'the',
#  'eight',
#  'main',
#  'islands',
#  ',',
#  'from',
#  'northwest',
#  'to',
#  'southeast',
#  ',',
#  'are',
#  'Niʻihau',
#  ',',
#  'Kauaʻi',
#  ',',
#  'Oʻahu',
#  ',',
#  'Molokaʻi',
#  ',',
#  'Lānaʻi',
#  ',',
#  'Kahoʻolawe',
#  ',',
#  'Maui',
#  ',',
#  'and',
#  'Hawaiʻi—the',
#  'last',
#  'of',
#  'these',
#  ',',
#  'after',
#  'which',
#  'the',
#  'state',
#  'is',
#  'named',
#  ',',
#  'is',
#  'often',
#  'called',
#  'the',
#  '"',
#  'big',
#  'island',
#  '"',
#  'or',
#  '"',
#  'Hawaii',
#  'island',
#  '"',
#  'to',
#  'avoid',
#  'confusion',
#  'with',
#  'the',
#  'state',
#  'or',
#  'archipelago',
#  '.',
#  'the',
#  'uninhabited',
#  'northwestern',
#  'hawaiian',
#  'islands',
#  'make',
#  'up',
#  'most',
#  'of',
#  'the',
#  'papah',
#  'ā',
#  'naumokuākea',
#  'marine',
#  'national',
#  'monument',
#  ',',
#  'the',
#  'United',
#  'States',
#  "'",
#  'largest',
#  'protected',
#  'area',
#  'and',
#  'the',
#  'fourth',
#  '-',
#  'largest',
#  'in',
#  'the',
#  'world',
#  '.',
#  'of',
#  'the',
#  '50',
#  'U.s.',
#  'states',
#  ',',
#  'Hawaii',
#  'is',
#  'the',
#  'eighth',
#  '-',
#  'smallest',
#  'in',
#  'land',
#  'area',
#  'and',
#  'the',
#  '11th',
#  '-',
#  'least',
#  'populous',
#  ',',
#  'but',
#  'with',
#  '1.4',
#  'million',
#  'residents',
#  'ranks',
#  '13th',
#  'in',
#  'population',
#  'density',
#  '.',
#  'two',
#  '-',
#  'thirds',
#  'of',
#  'the',
#  'population',
#  'lives',
#  'on',
#  "O'ahu",
#  ',',
#  'home',
#  'to',
#  'the',
#  'state',
#  "'s",
#  'capital',
#  'and',
#  'largest',
#  'city',
#  ',',
#  'Honolulu',
#  '.',
#  'Hawaii',
#  'is',
#  'among',
#  'the',
#  'country',
#  "'s",
#  'most',
#  'diverse',
#  'states',
#  ',',
#  'owing',
#  'to',
#  'its',
#  'central',
#  'location',
#  'in',
#  'the',
#  'Pacific',
#  'and',
#  'over',
#  'two',
#  'centuries',
#  'of',
#  'migration',
#  '.',
#  'as',
#  'one',
#  'of',
#  'only',
#  'six',
#  'majority',
#  '-',
#  'minority',
#  'states',
#  ',',
#  'it',
#  'has',
#  'the',
#  'country',
#  "'s",
#  'only',
#  'asian',
#  'american',
#  'plurality',
#  ',',
#  'its',
#  'largest',
#  'buddhist',
#  'community',
#  ',',
#  'and',
#  'the',
#  'largest',
#  'proportion',
#  'of',
#  'multiracial',
#  'people',
#  '.',
#  'consequently',
#  ',',
#  'it',
#  'is',
#  'a',
#  'unique',
#  'melting',
#  'pot',
#  'of',
#  'north',
#  'american',
#  'and',
#  'east',
#  'asian',
#  'cultures',
#  ',',
#  'in',
#  'addition',
#  'to',
#  'its',
#  'indigenous',
#  'hawaiian',
#  'heritage',
#  '.',
#  'settled',
#  'by',
#  'Polynesians',
#  'some',
#  'time',
#  'between',
#  '1000',
#  'and',
#  '1200',
#  'ce',
#  ',',
#  'Hawaii',
#  'was',
#  'home',
#  'to',
#  'numerous',
#  'independent',
#  'chiefdoms',
#  '.',
#  'in',
#  '1778',
#  ',',
#  'british',
#  'explorer',
#  'james',
#  'cook',
#  'was',
#  'the',
#  'first',
#  'known',
#  'non-polynesian',
#  'to',
#  'arrive',
#  'at',
#  'the',
#  'archipelago',
#  ';',
#  'early',
#  'british',
#  'influence',
#  'is',
#  'reflected',
#  'in',
#  'the',
#  'state',
#  'flag',
#  ',',
#  'which',
#  'bears',
#  'a',
#  'union',
#  'jack',
#  '.',
#  'an',
#  'influx',
#  'of',
#  'european',
#  'and',
#  'american',
#  'explorers',
#  ',',
#  'traders',
#  ',',
#  'and',
#  'whalers',
#  'arrived',
#  'shortly',
#  'after',
#  'leading',
#  'to',
#  'the',
#  'decimation',
#  'of',
#  'the',
#  'once',
#  'isolated',
#  'indigenous',
#  'community',
#  'by',
#  'introducing',
#  'diseases',
#  'such',
#  'as',
#  'syphilis',
#  ',',
#  'gonorrhea',
#  ',',
#  'tuberculosis',
#  ',',
#  'smallpox',
#  ',',
#  'measles',
#  ',',
#  'leprosy',
#  ',',
#  'and',
#  'typhoid',
#  'fever',
#  ',',
#  'reducing',
#  'the',
#  'native',
#  'hawaiian',
#  'population',
#  'from',
#  'between',
#  '300,000',
#  'and',
#  'one',
#  'million',
#  'to',
#  'less',
#  'than',
#  '40,000',
#  'by',
#  '1890',
#  '.',
#  'Hawaii',
#  'became',
#  'a',
#  'unified',
#  ',',
#  'internationally',
#  'recognized',
#  'kingdom',
#  'in',
#  '1810',
#  ',',
#  'remaining',
#  'independent',
#  'until',
#  'american',
#  'and',
#  'european',
#  'businessmen',
#  'overthrew',
#  'the',
#  'monarchy',
#  'in',
#  '1893',
#  ';',
#  'this',
#  'led',
#  'to',
#  'annexation',
#  'by',
#  'the',
#  'U.s.',
#  'in',
#  '1898',
#  '.',
#  'as',
#  'a',
#  'strategically',
#  'valuable',
#  'U.s.',
#  'territory',
#  ',',
#  'Hawaii',
#  'was',
#  'attacked',
#  'by',
#  'Japan',
#  'on',
#  'December',
#  '7',
#  ',',
#  '1941',
#  ',',
#  'which',
#  'brought',
#  'it',
#  'global',
#  'and',
#  'historical',
#  'significance',
#  ',',
#  'and',
#  'contributed',
#  'to',
#  'America',
#  "'s",
#  'decisive',
#  'entry',
#  'into',
#  'world',
#  'war',
#  'ii',
#  '.',
#  'Hawaii',
#  'is',
#  'the',
#  'most',
#  'recent',
#  'state',
#  'to',
#  'join',
#  'the',
#  'union',
#  ',',
#  'on',
#  'August',
#  '21',
#  ',',
#  '1959',
#  '.',
#  'in',
#  '1993',
#  ',',
#  'the',
#  'U.s.',
#  'government',
#  'formally',
#  'apologized',
#  'for',
#  'its',
#  'role',
#  'in',
#  'the',
#  'overthrow',
#  'of',
#  'Hawaii',
#  "'s",
#  'government',
#  ',',
#  'which',
#  'spurred',
#  'the',
#  'hawaiian',
#  'sovereignty',
#  'movement',
#  '.']

# %% [markdown]
# #  Using StanfordNLP and Part-of-Speech (POS)

# %%
# packages needed
# !pip install stanfordnlp
# !pip install --upgrade bleu


from nltk.tokenize import sent_tokenize
import stanfordnlp
#from bleu import list_bleu


# init packages
nltk.download('averaged_perceptron_tagger')


stf_nlp = stanfordnlp.Pipeline(processors='tokenize,mwt,pos')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/root/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/root/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/root/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
# function for restoring capitalization
def truecasing(input_text):
    # split the text into sentences
    sentences = sent_tokenize(input_text, language='english')
    # capitalize the sentences
    sentences_capitalized = [s.capitalize() for s in sentences]
    # join the capitalized sentences
    text_truecase = re.sub(" (?=[\.,'!?:;])", "", ' '.join(sentences_capitalized))
    # capitalize words according to part-of-speech tagging (POS)
    doc = stf_nlp(text_truecase)
    text_truecase =  ' '.join([w.text.capitalize() if w.upos in ["PROPN","NNS"] \
                                                   else w.text for sent in doc.sentences \
                               for w in sent.words])
    text_truecase = re.sub(r'\s([?.!"](?:\s|$))', r'\1', text_truecase)
    return text_truecase

# %%
truecasing(text)
# Out:
# 'Hawaii comprises nearly the entire hawaiian archipelago , 137 volcanic islands spanning 1,500 miles ( 2,400 km ) that are physiographically and ethnologically part of the polynesian subregion of Oceania. The state \'s ocean coastline is consequently the fourth - longest in the U.s. , at about 750 miles ( 1,210 km ). [ b ] the eight main islands , from northwest to Southeast , are Niʻihau , Kauaʻi , Oʻahu , Molokaʻi , Lānaʻi , Kahoʻolawe , Maui , and Hawaiʻi—the last of these , after which the state is named , is often called the" big island" or" Hawaii island" to avoid confusion with the state or archipelago. The uninhabited northwestern hawaiian islands make up most of the papahā naumokuākea marine national monument , the United States \' largest protected area and the fourth - largest in the world. Of the 50 U.s. states , Hawaii is the eighth - smallest in land area and the 11th - least populous , but with 1.4 million residents ranks 13th in population density. Two - thirds of the population lives on O\'ahu , home to the state \'s capital and largest city , Honolulu. Hawaii is among the country \'s most diverse states , owing to its central location in the Pacific and over two centuries of migration. As one of only six majority - minority states , it has the country \'s only asian american plurality , its largest buddhist community , and the largest proportion of multiracial people. Consequently , it is a unique melting pot of north american and east asian cultures , in addition to its indigenous hawaiian heritage. Settled by Polynesians some time between 1000 and 1200 ce , Hawaii was home to numerous independent chiefdoms. In 1778 , british explorer james cook was the first known non-polynesian to arrive at the archipelago ; early british influence is reflected in the state flag , which bears a union jack. An influx of european and american explorers , traders , and whalers arrived shortly after leading to the decimation of the once isolated indigenous community by introducing diseases such as syphilis , gonorrhea , tuberculosis , smallpox , measles , leprosy , and typhoid fever , reducing the native hawaiian population from between 300,000 and one million to less than 40,000 by 1890. Hawaii became a unified , internationally recognized kingdom in 1810 , remaining independent until american and european businessmen overthrew the monarchy in 1893 ; this led to annexation by the U.s. in 1898. as a strategically valuable U.s. territory , Hawaii was attacked by Japan on December 7 , 1941 , which brought it global and historical significance , and contributed to America \'s decisive entry into world war ii. Hawaii is the most recent state to join the union , on August 21 , 1959. in 1993 , the U.s. government formally apologized for its role in the overthrow of Hawaii \'s government , which spurred the hawaiian sovereignty movement.'

# %% [markdown]
# # Spacy

# %%
# !python -m spacy download en_core_web_lg
# !python -m spacy download en_core_web_sm

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

doc = nlp(text)

tagged_sent = [(w.text, w.tag_) for w in doc]
normalized_sent = [w.capitalize() if t in ["NN","NNS"] else w for (w,t) in tagged_sent]
normalized_sent[0] = normalized_sent[0].capitalize()
string = re.sub(" (?=[\.,'!?:;])", "", ' '.join(normalized_sent))

string
# Out:
# 2022-12-26 22:09:22.496563: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-26 22:09:23.586545: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Regular expressions

# %%
def uppercase(matchobj):
    return matchobj.group(0).upper()

def capitalize(s):
    return re.sub('^([a-z])|[\\.|\\?|\\!]\\s*([a-z])|\\s+([a-z])(?=\\.)', uppercase, s)

# %%
capitalize(text.lower())
# Out:
# 'Hawaii comprises nearly the entire hawaiian archipelago, 137 volcanic islands spanning 1,500 miles (2,400\xa0km) that are physiographically and ethnologically part of the polynesian subregion of oceania. The state\'s ocean coastline is consequently the fourth-longest in the U.S., at about 750 miles (1,210\xa0km).[b] the eight main islands, from northwest to southeast, are niʻihau, kauaʻi, oʻahu, molokaʻi, lānaʻi, kahoʻolawe, maui, and hawaiʻi—the last of these, after which the state is named, is often called the "big island" or "hawaii island" to avoid confusion with the state or archipelago. The uninhabited northwestern hawaiian islands make up most of the papahānaumokuākea marine national monument, the united states\' largest protected area and the fourth-largest in the world. Of the 50 U.S. States, hawaii is the eighth-smallest in land area and the 11th-least populous, but with 1.4\xa0million residents ranks 13th in population density. Two-thirds of the population lives on o\'ahu, home to the state\'s capital and largest city, honolulu. Hawaii is among the country\'s most diverse states, owing to its central location in the pacific and over two centuries of migration. As one of only six majority-minority states, it has the country\'s only asian american plurality, its largest buddhist community, and the largest proportion of multiracial people. Consequently, it is a unique melting pot of north american and east asian cultures, in addition to its indigenous hawaiian heritage. Settled by polynesians some time between 1000 and 1200 ce, hawaii was home to numerous independent chiefdoms. In 1778, british explorer james cook was the first known non-polynesian to arrive at the archipelago; early british influence is reflected in the state flag, which bears a union jack. An influx of european and american explorers, traders, and whalers arrived shortly after leading to the decimation of the once isolated indigenous community by introducing diseases such as syphilis, gonorrhea, tuberculosis, smallpox, measles, leprosy, and typhoid fever, reducing the native hawaiian population from between 300,000 and one million to less than 40,000 by 1890. Hawaii became a unified, internationally recognized kingdom in 1810, remaining independent until american and european businessmen overthrew the monarchy in 1893; this led to annexation by the U.S. In 1898. As a strategically valuable U.S. Territory, hawaii was attacked by japan on december 7, 1941, which brought it global and historical significance, and contributed to america\'s decisive entry into world war ii. Hawaii is the most recent state to join the union, on august 21, 1959. In 1993, the U.S. Government formally apologized for its role in the overthrow of hawaii\'s government, which spurred the hawaiian sovereignty movement.'

# %%
# NeMO - Punctuation and Capitalization Model

# %%
# !apt-get update && apt-get install -y libsndfile1 ffmpeg
# !pip install Cython
# !pip install nemo_toolkit[all]

# %%
# !pip install git+https://github.com/NVIDIA/NeMo.git

# %%
import nemo
from nemo.collections.nlp.models import PunctuationCapitalizationModel

# to get the list of pre-trained models
PunctuationCapitalizationModel.list_available_models()

# Download and load the pre-trained BERT-based model
model = PunctuationCapitalizationModel.from_pretrained("punctuation_en_bert")

# try the model on a few examples
model.add_punctuation_capitalization(['how are you', 'great how about you'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [65], line 1
# ----> 1 import nemo
#       2 from nemo.collections.nlp.models import PunctuationCapitalizationModel
#       4 # to get the list of pre-trained models
#
# ModuleNotFoundError: No module named 'nemo'
